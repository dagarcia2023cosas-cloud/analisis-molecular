# %% [markdown]
# # Configuración del Proyecto analisismolecular en Google Colab
#
# Este notebook configura el entorno de Google Colab para trabajar con el proyecto de análisis molecular.

# %%
# Clonar el repositorio e instalar dependencias
# !git clone https://github.com/tu-usuario/analisismolecular.git /content/analisismolecular
# %cd /content/analisismolecular
# !pip install -q -e .
# !pip install -q py3Dmol nglview plotly ipywidgets prody biopython rdkit-pypi

# %%
# Verificar instalación
from libreria_analisismolecular import colab
print(f"¿Entorno Colab? {colab.is_colab()}")
print("¡Proyecto listo para usar!")

# %% [markdown]
# ## Montar Google Drive (opcional)
#
# Ejecuta la siguiente celda para montar Google Drive y guardar/cargar datos.

# %%
from libreria_analisismolecular.colab import mount_drive
mount_drive()
